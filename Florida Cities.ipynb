# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Florida All Citites.csv")
df
# Out:
#     population_rank              city        county  population  land_area_mi  \
# 0               411        Marineland       Flagler          15          0.21
# 1               411        Marineland     St. Johns          15          0.21
# 2               410  Lake Buena Vista        Orange          24          3.00
# 3               409          Bay Lake        Orange          29         21.50
# 4               408         Lazy Lake       Broward          33          0.02
# ..              ...               ...           ...         ...           ...
# 409               5    St. Petersburg      Pinellas      258308         61.80
# 410               4           Orlando        Orange      307573        110.60
# 411               3             Tampa  Hillsborough      384959        114.00
# 412               2             Miami    Miami-Dade      442241         36.00
# 413               1      Jacksonville         Duval      949611        747.30
#
# ...

# %%
df["city_county"] = df["city"] + ", " + df["county"]

# %%
cities_counties = df[["city", "county", "city_county"]]
cities_counties
# Out:
#                  city        county               city_county
# 0          Marineland       Flagler       Marineland, Flagler
# 1          Marineland     St. Johns     Marineland, St. Johns
# 2    Lake Buena Vista        Orange  Lake Buena Vista, Orange
# 3            Bay Lake        Orange          Bay Lake, Orange
# 4           Lazy Lake       Broward        Lazy Lake, Broward
# ..                ...           ...                       ...
# 409    St. Petersburg      Pinellas  St. Petersburg, Pinellas
# 410           Orlando        Orange           Orlando, Orange
# 411             Tampa  Hillsborough       Tampa, Hillsborough
# 412             Miami    Miami-Dade         Miami, Miami-Dade
# 413      Jacksonville         Duval       Jacksonville, Duval
#
# [414 rows x 3 columns]
