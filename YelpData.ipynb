# %%
import pandas as pd
import numpy as np
import glob

import pyarrow as pa
import pyarrow.dataset as ds

from itertools import islice

# %%
businesses_df = pd.read_json("yelp_dataset/yelp_academic_dataset_business.json", lines=True)
# reviews_df = pd.read_json("yelp_dataset/yelp_academic_dataset_review.json", lines=True)

# %%
print(pd.__version__, pa.__version__)
# Out:
# 2.3.3 22.0.0

# %%
reader = pd.read_json(
    "yelp_dataset/yelp_academic_dataset_review.json",
    lines=True,
    chunksize=200_000,
    dtype_backend="pyarrow"
)

for i, chunk in enumerate(reader):
    chunk.to_parquet(
        f"yelp_dataset_parquet/reviews_part_{i:04}.parquet",
        index=False
    )

# %%
reader2 = pd.read_json(
    "yelp_dataset/yelp_academic_dataset_review.json",
    lines=True,
    chunksize=5_000  # tiny chunk just to inspect columns/dtypes
)
sample = next(reader2)
col_names = sample.columns.tolist()
print(col_names)
# Out:
# ['review_id', 'user_id', 'business_id', 'stars', 'useful', 'funny', 'cool', 'text', 'date']

# %%
dataset = ds.dataset("yelp_dataset_parquet", format="parquet")
print("rows:", dataset.count_rows())
print(dataset.schema)
# Out:
# rows: 6990280
# review_id: string
# user_id: string
# business_id: string
# stars: int64
# useful: int64
# funny: int64
# cool: int64
# text: string
# date: timestamp[ns]
# -- schema metadata --
# pandas: '{"index_columns": [], "column_indexes": [], "columns": [{"name":' + 1180

# %%
sorted_file_paths = sorted(glob.glob("yelp_dataset_parquet/reviews_part_*.parquet"))
reviews_df = pd.concat([pd.read_parquet(p, columns=col_names) for p in sorted_file_paths], ignore_index=True)

# %%
reviews_df.head(5)
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
# 2      3       0      0     0
# 3      5       1      0     1
# 4      4       1      0     1
#
#                                                 text                 date
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 4  Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6990280 entries, 0 to 6990279
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   review_id    string
#  1   user_id      string
#  2   business_id  string
#  3   stars        int64[pyarrow]
#  4   useful       int64[pyarrow]
#  5   funny        int64[pyarrow]
#  6   cool         int64[pyarrow]
#  7   text         string
#  8   date         timestamp[ns][pyarrow]
# dtypes: int64[pyarrow](4), string(4), timestamp[ns][pyarrow](1)
# memory usage: 4.6 GB

# %%
businesses_df.head(5)
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                               None
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %%
businesses_df.loc[businesses_df["state"] == "CO", "name"].nunique()
# Out:
# 3

# %%
businesses_df.loc[businesses_df["state"] == "FL", "name"].unique().tolist()
# Out:
# ['Temple Beth-El',
#  'Marshalls',
#  'Vietnamese Food Truck',
#  'Adams Dental',
#  "Zio's Italian Market",
#  "Gold's Gym",
#  "Charlie's Market",
#  'Roman Forum',
#  "Joe's Pizza",
#  'Educational Outfitters',
#  'Publix Super Market',
#  'Holly Nails & Spa',
#  'Top Shelf Sports Lounge',
#  'Impasto',
#  'The Pearl',
#  'Walmart Supercenter',
#  'Mirror Lake Community Library',
#  'Laser Spine Institute',
#  'Meineke Car Care Center',
#  'The Cake Drip',
#  'Professional Healthcare of Pinellas',
#  'Chipotle Mexican Grill',
#  'Carsmetics',
#  'Tuffy Tire & Auto Service Center',
#  'Bay Area Appliance',
#  'Trust Me BBQ',
#  "Kinjo's Japanese Restaurant",
#  'PDQ Temple Terrace',
#  'Seaview Condominiums',
#  'Aussie Grill',
#  '530 Pub & Grill',
#  'Option 1 Barber Shop',
#  'Zesty Tsunami',
#  "O'Briens Irish Pub",
#  'Thach Used Tires',
#  "Lee Roy Selmon's",
#  'Union on Fletcher',
#  'Nails & Beauty Lounge',
#  'Four Green Fields',
#  'Cafe Con Leche',
#  'Master Bait and Fishing Supplies',
#  '1-275 Rest Area Manatee County Mile 7',
#  'Sake House',
#  'Camden Bay Apartments',
#  'Bulls Barbershop',
#  'Blow Bar Express Styling Salon',
#  'Accurate Window & Screen',
#  'Williams Sub Shop',
#  'Bronze Lady Home Furnishings',
#  'South Cleaner & Tailor',
#  'Brandon Burgers',
#  'Heritage Hardwood Floors',
#  'Splash Car Wash & Lube',
#  'G Peppers Grill & Tavern',
#  "Kids 'R' Kids of Waterset",
#  'The Hideout Coffee House',
#  'Pretty Nails',
#  'Bodyworks Salon & Day Spa',
#  'Contempo Hair Salon',
#  'MedExpress Urgent Care',
#  'Mai Thai Restaurant',
#  'The Home Depot',
#  'Soho Oasis Cafe',
#  'Noble Crust',
#  "Domino's Pizza",
#  'The Silo Eatery Coffee Bakery',
#  'Main Exchange Barber Shop',
#  'El Sabor Boricua',
#  'Petco',
#  'Domain Home Accessories & Gallery',
#  'Dental Care at Quail Hollow',
#  'Coliseum Ballroom',
#  'Lens Crafters',
#  "L'Occitane en Provence",
#  'MOSI Food Truck Rally',
#  'Parasailing The Pass',
#  'The Corner Cafe and Deli',
#  'The Hip Hop Sandwich Shop',
#  'Wildout Animal & Pest Removal Tampa',
#  'Pretty In Paint',
#  'Digestive Diseases Associates of Tampa Bay',
#  'Appliance Center',
#  'Affordable Lock & Security Solutions - Tampa',
#  'The Pet Trailer Mobile Grooming',
#  'Hibiscus Spa',
#  'Nutrishop',
#  'Westchase Compounding Pharmacy',
#  "Reeder's Auto Tint & Ceramic Coatings",
#  'Hands On Bicycle',
#  'Foolish Pride Tattoo Company',
#  'The Bricks',
#  "Big Mike's BBQ",
#  "Dunkin'",
#  'Reno Downtown Joint',
#  'Jos A Bank',
#  'Gasparilla Pirate Festival',
#  'Starbucks',
#  'James L Frank Door Service',
#  'ZigZag Scallop',
#  "Auntie Anne's",
#  'Bagelicious and More',
#  'Divine Designs Floral & Tropicals',
#  'B&M Hardwood Flooring',
#  'Manor Riverwalk Luxury Apartments by TRG Management Company',
#  'Xtreme Adventures',
#  'Wesley Chapel Florist',
#  'Snellgroves Restaurant',
#  'McMahan Hair Salon',
#  'Adventure Coast Fun Park',
#  "Bill's European Autoworks",
#  'Journeys Shoes',
#  'West Coast Awnings',
#  "McDonald's",
#  'FedEx Office Print & Ship Center',
#  'Casita Taqueria',
#  'Hippie Hi',
#  'Pita Kebob',
#  'Rituals Aveda Salon',
#  'Tire Choice Auto Service Centers',
#  'Tin Drum Asia Cafe',
#  'Angelica Beauty and Waxing',
#  'Bottom Zupp "Floor Removal Experts"',
#  "Kathy's Airport Limousine Service",
#  'Tire Kingdom',
#  'China City Restaurant',
#  'Stylist Inside',
#  'Andro Beavers & Associates',
#  '365 Caffe Italiano',
#  'CVS Pharmacy',
#  "Aj's Bikes and Boards",
#  'Indigo Point',
#  'Absolute Luxury',
#  'JOANN Fabrics and Crafts',
#  'One Hour Heating & Air Conditioning - Largo',
#  'KELP Sushi Joint',
#  'DND Plumbing',
#  'Optilife Chiropractic',
#  "Hardee's",
#  'CD Roma Restaurant',
#  'Glow by Natalia Barlow',
#  'J C Automotive Service',
#  "O'Shucks Seafood & Grill",
#  "John's Pass Waverunners",
#  'Windsong Charters & Boat Rentals',
#  "Sonny's BBQ",
#  'Porpoise Pub',
#  "Gandolfo's New York Deli",
#  'Aqua Terra Salon & Spa',
#  "Ted's Luncheonette",
#  'Jiffy Lube',
#  'Gifted Hands Barber Shop',
#  'Esthetic Style',
#  'Saks OFF 5TH',
#  'Legacy Coins',
#  'Advance Auto Parts',
#  'The Humming Bird Jerk house',
#  "Stefanec's South Barber Shop",
#  "Whaley's Blazin BBQ",
#  'Save A Lot',
#  'Golden Spirit Alpaca Ranch',
#  'Sonic Transportation & Logistics',
#  'Clearwater Travel Resort',
#  'BayLife Physical Therapy and Rehabilitation- St. Petersburg',
#  'Roll A Guard',
#  "Portofino's Italian Kitchen",
#  'Lincoln Tactical',
#  'Largo Police Department',
#  'Dio Modern Mediteranean',
#  'Nu Look Lawn Service Corp.',
#  'Terra Sur Cafe',
#  'Meat Depot',
#  'Taza Mediterranean Grill',
#  'Modern Moose Studios',
#  'Vision Ace Hardware',
#  'Studio510',
#  'Tsunami Japanese Steakhouse',
#  'Tampa Smile',
#  'Advantage Rent A Car',
#  "Smokin' Out",
#  'Sawgrass Tiki Bar',
#  'El Rancho Mexican Grill',
#  'Taco Bell',
#  "Sweet Pete's",
#  'Regal Cinema',
#  'Smart Wheel Moving',
#  'US Heating and Air Conditioning',
#  'CASA Community Thrift Shop',
#  "Beef 'O' Brady's",
#  'Florida Auto Exchange',
#  'Chase Bank',
#  "Fuzzy's Taco Shop",
#  'Twisted Metal Offroad & Diesel',
#  'The Bungalows',
#  'Turkey Creek Animal Hospital',
#  'Orchid Thai Foods',
#  '25 Roses $10',
#  'Causeway Beach Wash',
#  'Bank of America Financial Center',
#  'Banko Overhead Doors',
#  'TownePlace Suites Tampa North/I-75 Fletcher',
#  'Luminous Electric',
#  'Valbona Salon',
#  'Harvest Bowl Eatery & Market',
#  'Lutz Mail Depot - FedEx',
#  'Frost & Bean Gelato & Coffee Laboratory',
#  'Island Fin Poké',
#  'Get Air New Port Richey',
#  'FYZ Auto Care',
#  'South Beach Tanning Company',
#  'Wheel Cafe',
#  "Miami's Best Cuban By Los Maruchos",
#  'AT&T Store',
#  'Vino Simpatico',
#  'Independence Square Barber Shop',
#  'All Makes Collision Center',
#  'Clayman Thyroid Center',
#  'Thriller Clearwater',
#  'Riverview Flea Market',
#  'GTE Federal Credit Union',
#  'Surf and Turf Cafe',
#  'St. Pete Beach',
#  'Publix Supermarket at Southgate Shopping Center',
#  "Banana's Music",
#  'Skincare Solutions',
#  'Heavenly Nails I',
#  'Salons by JC',
#  'La Casa de Pan de Yuca',
#  'Froyo Fresh',
#  'Incredible Underwater LED Lights',
#  "Sayroo's Bakery and Grocery",
#  'Basimo Beach Cafe',
#  'Stonefire Tavern',
#  "Fray's Donut House",
#  'Sweeties By Mili',
#  'Tampa Vapor',
#  'Sweet Tea Celebrations',
#  'Busy Nails',
#  'Country Squire Barber-Style Shop',
#  'Julian Restaurant',
#  'MY SALON Suite® of St. Petersburg',
#  "McAnderson's House of Brews",
#  'Golden Corral Buffet & Grill',
#  'Advanced Dermatology & Cosmetic Surgery of Largo',
#  'J R Farms',
#  'United Water Restoration Group of Tampa',
#  'Amore Mio',
#  'Pop-A-Lock',
#  'YO! Sushi',
#  'Lily',
#  'Able Builders, Inc',
#  'Ambiance Salon & Spa',
#  "Corey's Bakery",
#  "Howie's Sun City Center Plumbing Services",
#  'The Fishin Chicken Food Truck',
#  'Salty Lime Cantina',
#  'Paradise Pizza Cafe',
#  'The Local Draught House',
#  'EATS! American Grill',
#  'Caladesi Honeymoon Ferry Service',
#  "Trip's Diner",
#  'Zorba',
#  'Finish Line',
#  'The Eye Institute Of West Florida',
#  'AAMCO Transmissions & Total Car Care',
#  'Antiques To Aardvarks',
#  'Gizmo Pros',
#  'New Hong Kong Chinese Restaurant',
#  'Ichicoro Ane',
#  'GrowHealthy - Brandon',
#  'Superior Transmissions',
#  'Breakfast Club',
#  'Odessa Family Restaurant',
#  'Mr.Smoke',
#  'China Wok',
#  'Out of the Closet - St. Petersburg',
#  'Beauty Depot',
#  'The Little Lamb',
#  'Villagio Cinemas',
#  'Twistee Treat - New Tampa',
#  "Zaxby's Chicken Fingers & Buffalo Wings",
#  'Tatums Bait & Tackle',
#  "Suzie Q's Diner",
#  '49th Street Tires Clearwater',
#  'Kobe Japanese Steakhouse',
#  'Hilton Garden Inn St Pete Beach',
#  'Stangherlin Chiropractic Clinic',
#  'Gu Wei Noodles & Grill',
#  'CarHeroes',
#  "Women's Care Florida",
#  'The Good Life Smoke Shop',
#  'Grand Shores West Resort',
#  'Super Heat and Air',
#  'Pitas Republic',
#  'Subway',
#  "Georgette's Boutique &Shoe Salon",
#  'Lincare',
#  'Ibritz Flower Decoratif',
#  "Zeko's Mediterranean Grill",
#  'Lexus of Clearwater',
#  'Hair Force Barber Shop',
#  'Tryst Gastro Lounge',
#  'Happy Pets Inn',
#  'Crunch Fitness - Bloomingdale',
#  'Riviera Pools',
#  'Mexico Lindo',
#  'Floor Groomers',
#  "Michelle's Ultimate Car Care",
#  'DDS Lab',
#  'Imagine That',
#  'Boulevard Salon',
#  'Urology Specialists of West Florida',
#  'Assuregreen Property Services',
#  'Salon Lofts Tyrone Square',
#  'Burger King',
#  'Tampa Roof Repair',
#  'Circle K',
#  'Florida Power Yoga',
#  'Super China Chinese Restaurant',
#  'Optical Outlets',
#  'Cheap Car Insurance',
#  'Flagship Title',
#  'Worlds Most Unusual Dollar Store & More',
#  'Davis Island Yacht Club',
#  'Infinite Descent',
#  "Rogo's Window Cleaning",
#  'Winn-Dixie',
#  "JJ's Barbeque",
#  'Tampa Bay Dental Implants & Periodontics',
#  'D-Town Bar & Grill',
#  'Paola Beauty Boutique',
#  'Sacred Lands',
#  'Confidential Accounting, CPA',
#  'Anani Bistro',
#  'Farina Orthodontics',
#  'David’s Bridal',
#  'Side Splitters Comedy Club',
#  "Guido's Italian Restaurant",
#  'Sulas',
#  'Simply Self Storage - Land O Lakes',
#  'ABC Pizza House',
#  'Katz Foot and Ankle',
#  'Dwell at Bay Crossing by Pinnacle Family of Companies',
#  'Lan Zhou Lamen',
#  'Dennis Hernandez & Associates',
#  'Ashley HomeStore',
#  "Season's Fresh",
#  'Thai 5 Fast Food',
#  'Osaka',
#  'Mahal Bazaar',
#  'Steak ’n Shake',
#  'Thrive! Wellness Center',
#  "Charlie's Re-Sod",
#  "Badar's Hair & All",
#  'Cakes Plus',
#  'Oldsmar Family Barber Shop',
#  'Treemart',
#  'A & A White Sewing Hub',
#  'Tires Plus',
#  "Wendy's",
#  'Kidtopia',
#  'Channel Park Trailhead',
#  'Midgard Self Storage',
#  "Albisia's Jewelry",
#  'Art Ryan Motor Werks',
#  'Adora Body Sculpting Clinic',
#  'Florida Leak Locators',
#  'Winn Dixie',
#  'Massage Studio',
#  'RaceWay',
#  'USPS',
#  'N-41 Bingo',
#  'Stefano Greek Italian Restaurant',
#  'Mark Rossmiller - State Farm Insurance Agent',
#  'Shallow Point Charters',
#  "Blair's Air Conditioning & Heating",
#  "Exodus Women's Center",
#  'Clothes Mentor',
#  'First Watch',
#  'Walgreens',
#  'Great Expressions Dental Centers Cross Creek',
#  'Belleview Biltmore Resort & Spa',
#  'Carnival Cruise Lines',
#  "JB'S Island Cafe",
#  "Dillard's",
#  'Tampa Garden Club',
#  'Great Clips',
#  'Hirois Ocean Grill',
#  'RaceTrac',
#  'Five Star Pizza',
#  'Capricho’s',
#  'Masterpiece Watch Restoration',
#  'Pineywoods Realty',
#  'Ranch House Restaurant',
#  'Westside Animal Clinic',
#  'Simply Done Donuts',
#  "Red's On the Blvd",
#  'The Whiskey',
#  'The Ivy',
#  "Jesse's Steak and Seafood",
#  "Leslie's",
#  'Staples',
#  'St. Pete Pressure Washing',
#  'Key West Shrimp Company',
#  'Dooners',
#  "Kul's Bar & Grill",
#  'Salty Shamrock Fishing Charters and Events',
#  'Florida Dental Centers',
#  'Toki Sushi',
#  'The Burg Diner',
#  'Cellphone MD',
#  'Craft & Curd',
#  'Alvarez  Authentic Latin Food',
#  'A Modern Line',
#  'Wizard Concrete',
#  'The Bungaleaux on Central',
#  'Oddities and Antiques',
#  'Bella Under the Sea Spa, Inc.',
#  "Shorty's Breakfast & Gourmet Deli",
#  'Preachers BBQ',
#  'Jungle Bills Tiki Grill',
#  'Yah Mon',
#  'Crabby Bills Clearwater Beach',
#  'Livefit Spa',
#  'Awe For Pets Sake',
#  'Hiccups & Churroholic',
#  'The Local',
#  'Rico’s Food Factory',
#  'Makin Waves',
#  'A Plus Soft Wash',
#  "Jin's Alterations",
#  'Tokyo',
#  'Jasmine Thai',
#  "Joy's Nails",
#  'Nirvana Day Spa',
#  "AJ's Nail Spa",
#  'Custom Classics',
#  'Windsor Club at Legacy Park',
#  'New Generation Ink Tattoo Studio',
#  'Buddy Brew - Hyde Park',
#  'Green Locus',
#  "Angie's Restaurant",
#  'Fade Masters 5',
#  'Family Fence Company',
#  "Brenda's On the Causeway",
#  "Ray's Vegan Soul",
#  'Rogers Landscape Supply',
#  'Chic Venue',
#  "Jerry's Drive Thru",
#  'Holiday Electric',
#  "Tommy's Express® Car Wash",
#  'Shoot Straight',
#  'Party City',
#  'Discovery Point Suncoast',
#  'Sudsy Paws Mobile Dog Grooming',
#  'Maureen B. Gauzza Public Library',
#  'Ceramic Creations',
#  'Submarine Gyro Town',
#  'Suburban Propane',
#  "Hubbard's Marina",
#  'Nicks Gyros and Subs',
#  'Super Sports & Scuba',
#  'TGH Family Care Center',
#  'Coral Reef Aquariums',
#  'Irie Bay Cafe',
#  'Scientology Information Center',
#  "Frankie's Deli",
#  'The Enerjuicer',
#  'Deans Electrical Service',
#  "Kane's Furniture",
#  'Kuchi Sushi & Hibachi',
#  'Raceway 980',
#  'KFC',
#  'The Flying Bridge',
#  "Kally K's Steakery & Fishery",
#  'Truly Nolen Pest & Termite Control',
#  'Watergarden Inn At the Bay',
#  "Frank's Diner",
#  'China Star',
#  'Walmart Neighborhood Market',
#  '66 Q-pot',
#  "Salty's Island Bar & Grille",
#  'Marathon Gas',
#  'Diamond Hill Golf and Country Club',
#  'Mike Stevens - On Target Golf Schools',
#  'Bayside Pool Services',
#  'StorQuest Self Storage',
#  'Yama-Taiyo Japanese Cuisine & Sushi Bar',
#  'Pizza Hut',
#  'Shangri-La Bath & Sauna',
#  'El Manjar',
#  'Country Inn & Suites Radisson',
#  'Visconti at Westshore',
#  'Fitlife Foods - Wesley Chapel',
#  'Florida School of Woodwork',
#  "Kim's Cuban Sandwich Shop",
#  'Hertz Rent A Car',
#  'Riverview Veterinary Hospital',
#  'Tijuana Flats',
#  'Pet Supermarket',
#  'Yesner Law',
#  'Popeyes Louisiana Kitchen',
#  'Advanced Endodontics of Tampa Bay',
#  'Union Burger',
#  'Sea Dog Cantina',
#  'Pezzella Family Dentistry',
#  "MadaVera's Original Hero & Bakery",
#  'Vitale ENT',
#  'American Social',
#  'Hsn Retail Outlet',
#  'Palm Harbor Flooring',
#  'Beyond Bones Chiropractic & Wellness',
#  'Roberts Meats And Catering',
#  'XT Munchies',
#  'Cosmic Donuts',
#  'South Beach Condo Hotel',
#  'Café Cuba',
#  'Newsom Eye - South Tampa',
#  'Citylife Church',
#  'Westfall Roofing',
#  "Miss Merrie's Sweets & Treats",
#  'Bistro66',
#  'SOHO Cycling',
#  'Ashley Izquierdo',
#  '4th Street Pizza',
#  'The Lodge',
#  "Hungry Howie's Pizza & Subs",
#  'Village Inn',
#  'J.D. Byrider',
#  'Avenue Nails & Spa',
#  'The Health Associates of Tampa',
#  "Murphy's Pet Parlor",
#  "Mona's Floral Creations",
#  'Salt Pines',
#  "Chicago's Stuffed Pizza",
#  'Janie and Jack',
#  "Franci's Cafe",
#  'Veteran Tree Service',
#  'Ballyhoo Grill',
#  'Bella Bella Dominican Hair Salon',
#  'ALDI',
#  'Main Street Renewal - Tampa',
#  'Amy Creech-Gionis, DMD',
#  'Heaven Nails & Spa',
#  'Macey E. McAleer & Associates',
#  'Kindness Animal Hospital',
#  'Mosaic',
#  'General RV Center',
#  'PetSmart',
#  'New Tampa Karate',
#  'Wall St Pizza',
#  'Haveli Indian Cuisine',
#  'Bardmoor YMCA',
#  'Fifth Third Bank',
#  'Great Expressions Dental Centers - Citrus Park',
#  'Start2Finish Flooring',
#  'Sucre Table',
#  'J&R Moving',
#  'The Cat Hospital Of Tampa Bay',
#  'Wingstop',
#  'Regions Bank',
#  "McNatt's Cleaners",
#  'Liquid Art Tattoo',
#  'Massage Envy - Lutz',
#  'Thank You Mama',
#  "Children's Urology Group",
#  'Certegy Payment Services',
#  'River Heights Dry Cleaners',
#  'The UPS Store',
#  'Love Nail & Spa',
#  'Seagate Chiropractic - Maximized Living Health Center',
#  'Gott Glass Gallery and Phoenix Studio',
#  'JB Factory Flooring',
#  'Le Mouton Noir Bakehouse',
#  "Alfresco's",
#  'Psychotic Ink',
#  'Shark Coast Tactical Brandon',
#  'Sorelle Restaurant',
#  'Action Towing',
#  'Poké Poké Bowl',
#  'AFC URGENT CARE SEMINOLE',
#  'Fantastic Sams Cut & Color',
#  'Heim Regenerative Medicine Center',
#  "Chili's",
#  "Ryan's Meat Market & Deli",
#  "Christian's Handyman Services",
#  'Portofino Apartment Homes',
#  'All Access Vapor',
#  'Combat Pest Control',
#  'ABC Tires & Auto',
#  "Marty's Cafe",
#  'Divine Connections Massage & Spa',
#  'Slice Of Heaven Pizza',
#  'TGH Urgent Care powered by Fast Track',
#  'uBreakiFix',
#  '7-Eleven',
#  "Joel's Pizza Palace",
#  "Deb's Laundry",
#  'The Cleaning Authority - Tampa',
#  'Ravens and Rockers',
#  'ENT Associates',
#  'Annex',
#  'Stigma Ink',
#  "Leverock's Seafood House of St Pete Beach",
#  'Gunslingers',
#  'Taps Pest Services',
#  'Epperson',
#  'Bay Area Auction & Antique Marketplace',
#  'Imperial Asian Buffet',
#  'Lucky 7 Foods',
#  'The Brunchery',
#  'Pho Cuong',
#  'Yasemin Market',
#  'Brick City Eatery',
#  'Timepiece Fix',
#  'Reserve at Brandon',
#  'Mr Ice Cream',
#  'Romanos Pizza Express',
#  'Father and Son Tires',
#  'Dragon City',
#  'PHDermatology',
#  'Swigwam Beach Bar on Corey',
#  'Rotech',
#  'Sultan Market',
#  'David C. Gross Funeral Home',
#  'Brandon Bagels',
#  'Gourmet Pizza Company',
#  'Mole y Abuela',
#  'Tour America',
#  'Skyline Chili',
#  "Hackett's Causeway Cafe and Creamery",
#  'Redman Fence and Wood Productions',
#  'Casablanca Barber Shop',
#  'Great Lakes Christmas Tree Farms',
#  "Sami's Bakery",
#  'The Great American Bagel',
#  'The Art Supply Store',
#  'Sea Turtle Restaurant',
#  'Ruth Hair Salon',
#  'German Bistro',
#  'Happy Ending Food Truck',
#  'Ithai & Sushi Restaurant',
#  'Los Comparres',
#  'Express Oil Change & Tire Engineers',
#  'Gasparilla Pizzeria & Growlers',
#  'Strickland Vintage Watches',
#  'Tampa Top Acupuncture & Herbs',
#  'Keystone Farmers Market',
#  'Jos. A. Bank',
#  "Rickenbacker's",
#  'Heritage Tattoo',
#  'Palm Harbor Auto Service',
#  'Shalimar Fine Jewelers',
#  'The Disco Dolls',
#  "Arby's",
#  'South Tampa Vape',
#  'YogaSix - Westchase',
#  'Main Street Bakery NPR',
#  'Palm Pavilion Inn',
#  'Twistee Treat - Sheldon',
#  'Supercuts',
#  'Blend Lounge',
#  'Beach Bods Gym',
#  'Hot Wax Glass Ybor',
#  'Ricks Tiki Bar',
#  'El Dorado - St. Petersburg',
#  'Timpano Hyde Park',
#  'Sponge Docks Seafood Festival',
#  'Subaru of North Tampa',
#  'Coney Island',
#  'Esporta Fitness',
#  'LC Technology International',
#  "Darrell and Sharon's Park Street Diner",
#  'Tender Touch Cleaners',
#  'Largo Golf Course',
#  "Fred's",
#  'Kind Grinds',
#  'Courtyard by Marriott St. Petersburg Clearwater',
#  'Pupuseria & Cafeteria Centroamericana',
#  'Verizon Wireless Sales',
#  'Redington Long Pier',
#  'Grain and Berry',
#  "BJ's Wholesale Club",
#  'Ocean Chiropractic & Wellness Center',
#  'Ballast Point Park',
#  'Discount Glass & Mirror',
#  'Earl of Sandwich',
#  'Centro Cantina',
#  '2001 Odyssey',
#  'Adam & Eve Day Spa',
#  'Rejuvenation Spa',
#  'Hampton Inn & Suites Tampa-Wesley Chapel',
#  'Instead of Flowers',
#  'Sun Line Cruises',
#  'Gators Cafe & Saloon',
#  'Uncle Maddios Pizza',
#  'Paramount Wigs',
#  "Beanie's Bar & Sports Grill",
#  'Finley & Phillips Hair Salon',
#  'The Bikini Boutique',
#  'Checkers',
#  'Larry Miller',
#  "Capriotti's Sandwich Shop",
#  'Ava',
#  'Pasadena Eye Center',
#  'Bayscape at Heritage Isles',
#  "Harry's Beach Bar",
#  'Big Lots',
#  'Automotive Custom Group',
#  'Double Decker',
#  'Southbay Animal Hospital',
#  'Best Choice Cleaners',
#  'budget rental car',
#  'Mise En Place Bistro',
#  'Pediatric Surgery Centers',
#  'Books-A-Million',
#  'Chick-fil-A',
#  'Driftwood Cafe',
#  'FedEx Ship Center',
#  'Nike Factory Store',
#  'German Motor and Auto Care',
#  'Fred E Marquis Pinellas Trail',
#  'Helping Hands Thrift Store',
#  'Body & Soul Massage',
#  'Enterprise Car Sales',
#  'Plato Latino',
#  'Ace Tire & Auto Repair',
#  'Ross Dress for Less',
#  'The Gasparilla Bar',
#  "Honey's",
#  'Anytime Fitness',
#  'Harbor Freight Tools',
#  'Sherwood Florist',
#  'Manhattan Nails Salon',
#  'Dietz Cleaning',
#  "Luigi's Italian Restaurant",
#  'Munyan Painting, Roofing, and Restoration',
#  "Nidia's Latin Grill",
#  "Suzi's Restaurant",
#  'Hayman Jewelry Co',
#  'Perks Coffeehouse',
#  "Carino's Italian Ristorante",
#  "Hot Willy's",
#  'Kapok Special Events Center',
#  'Second Image',
#  'Chopstix',
#  'Taco Bus',
#  'Greenhouse Environmental',
#  'The Massage Center',
#  'Bed Pros Mattress',
#  'Akira Hibachi & Sushi Bar',
#  'SpinNations Skating Center',
#  'Omaha Steaks',
#  'Millenium Barber Shop',
#  'Indian Rocks Christian School',
#  'T-Mobile',
#  'Scuba Haven',
#  'Bubble Down Car Wash',
#  'Naviera Coffee Mills',
#  'La Giraldilla',
#  'Jack Joyner Heating & Air Conditioning Company',
#  "Lowe's Home Improvement",
#  'StarLite Sapphire',
#  'Forever 21',
#  'Taqueria El Sol',
#  'China King',
#  'Strong Vision Center',
#  'Kmart',
#  'Sweet Island Vibes',
#  'Senica Air Conditioning',
#  'Monstah Lobstah',
#  'Publix Super Markets',
#  'Xtreme Tacos',
#  'The Eye Institute of West Florida',
#  'Boyd Hill Nature Preserve',
#  'Diva Nail & Spa',
#  'Floor Depot',
#  "Friend's Plumbing",
#  'Tampa Pizza Co - Westchase',
#  'Kaisen Sushi',
#  'Hilltop Cafe',
#  'Mamas Kitchen',
#  'U-Haul Moving & Storage of East Tampa',
#  'Family Fitness Centers',
#  "Roger's Chicago Beef & Pizza",
#  "Harold's Feed & Pet Supply",
#  "Advanced ENT's of Tampa Bay",
#  'Embassy Suites by Hilton Tampa Downtown Convention Center',
#  'Ebb Tide Motel',
#  "Woody's Watersports",
#  'One Lucky Dog',
#  'Pressuremaxx',
#  'National Heating & Air Conditioning',
#  "K's Luxury Nails",
#  'Pier House 60 Beach Marina Hotel',
#  'American Spirits',
#  "Glazer Children's Museum",
#  'Smoke Shop Zone',
#  'E & E Gliddon Air Conditioning',
#  'Regis Salon',
#  'Firehouse Subs',
#  "Shane's Well Drilling & Pump Repair",
#  'Frontier Steakhouse',
#  'Hibiscus Hair Studio',
#  'Dody',
#  'Let Them Eat Cake',
#  'Pho An Hoa Restaurant',
#  'La Belle Riviere Brandon',
#  'Extreme Fence',
#  'Beach Island Brewery',
#  "Great Expressions Dental Centers - Land O' Lakes",
#  'ARTicles Art Gallery & Custom Framing',
#  'Happy Pet Grooming Salon',
#  'Taqueria Chazumba',
#  'Pet Safari',
#  'PSTA',
#  'Stouts Auto',
#  'Above The Salt Cafe',
#  'Hernando Animal Hospital',
#  'Delano At Cypress Creek',
#  'West Shore Construction',
#  'Alley Auto Tint',
#  'Smith & Associates Real Estate',
#  'Case Plumbing',
#  'Beck Gallery',
#  'The Spaniard',
#  'Le Palace Clearwater',
#  'The Hole In The Wall Bar-Tampa',
#  'Natasha Radosavljevic, DDS',
#  'Sleep Inn Wesley Chapel - Tampa North',
#  'Beantown Pub South',
#  'Rent Max',
#  'The Marq Highland Park',
#  'Riverview Fresh Market',
#  'Kung Fu Tea',
#  'Gran Agave',
#  'floridacentral Credit Union',
#  'Porsche Tampa',
#  "Terry's Automotive",
#  'Ybor City Food Tours',
#  'Hair Force',
#  'Florida Avenue Brewing Co.',
#  "Pepo's Cuban Cafe",
#  '7 Layers Bakery',
#  'Blue Lagoon Carwash & Laundry',
#  'Crest Lake Dog Park',
#  'Daniels Chevrolet',
#  'Gro Styles',
#  'Brick & Mortar',
#  '$1.99 Cleaners',
#  'Mr. & Mrs. Crab',
#  'Allegra Spa Cafe',
#  'Asados Al Carbon',
#  'The Salvation Army Family Store & Donation Center',
#  'AM Auto Parts',
#  "Oz Gentlemen's Club",
#  'Elevation Coffee Roasters',
#  'Shenaniganz Chill and Grill',
#  'Forever Young Aesthetics',
#  "Miguel's Latin Market",
#  'Boizao',
#  'All Ages Dental Spa',
#  'Frog Creek Rv Campground',
#  'Family Express Urgent Care',
#  'China Sea',
#  'Kurry Xpress',
#  'Medicine River Animal Hospital',
#  "Papa John's Pizza",
#  'Asian Kitchen',
#  'H20℃',
#  'Suitsupply - Tampa',
#  'AMF Clearwater Lanes',
#  'Sips Specialty Coffee House',
#  'City Nails',
#  'That Little Bakery Cafe',
#  'Sushi-Haru',
#  'Lifestyle Family Fitness',
#  'Homestyle Deli & Pizza Resturant',
#  'Isaacs World Famous',
#  'Daba Nails & Waxing',
#  'Little Road Farm Stand',
#  'Auracle Salon',
#  'Seasons Cafe & Bakery',
#  'Rosy Nails',
#  'Royal Oriental Rugs',
#  'Louis Pappas Fresh Greek',
#  "Applebee's Grill + Bar",
#  'Apps & Tapps Trinity',
#  'REM Air Conditioning of Tampa',
#  'Florida Mattress And Furniture ',
#  'Home Inspection Professionals',
#  'Life Storage',
#  'Planet Fitness',
#  'Atlas Appliance Service',
#  "Marco's Pizza",
#  'Pinellas Tree Service',
#  'The Woodhouse Day Spa - St Petersburg',
#  'Urban Oasis Hydroponic Farm',
#  'Red Mesa Restaurant',
#  'Buddy Brew Coffee ',
#  'Coast Dental',
#  'Rock Bottom Divers',
#  'Grand Hyatt Tampa Bay',
#  'Pure Hockey',
#  'Angela Clifton Photography',
#  'Los Comales',
#  'Ken Barrett Air Conditioning, Inc',
#  "Keith's Oaks Bar & Grill",
#  'IL Terrazzo',
#  'Rebecca Gay Doula CBE CLC',
#  "Jimmy John's",
#  'Coolco Air Conditioning & Refrigeration',
#  'Number One Nail Salon',
#  "Esmeralda's Boutique",
#  'BMC Mattress Clearwater',
#  "McAlister's Deli",
#  'Mang Dentistry',
#  'Five Guys',
#  'Olympus pools - Florida',
#  'Quigley Inspection Services',
#  'The Honu',
#  "Tangelo's Grille",
#  'Publix',
#  '5 de Mayo Bakery',
#  'Wild Fork Foods',
#  'Marshalls Department Store',
#  'iTREKKERS',
#  'Courtyard by Marriott Tampa Oldsmar',
#  'Room 901',
#  'Target',
#  'Acapulco Loco',
#  'Italian Club',
#  'Ohana Cafe',
#  'Doctor Diet Centers',
#  'Tree Dragons Tree Service',
#  'East Bay Animal Hospital',
#  "Olga's Bridal & Boutique",
#  'Max Photo & Decor',
#  "Craig's Insulation",
#  'Serendipity Salon & Spa',
#  'Creative World School',
#  'Irwin Photographics',
#  'Green Iguana Bar & Grill',
#  'Restoration Hardware',
#  'Fung Garden',
#  'Tantra',
#  'Kimberly Home Thrift Shoppe',
#  'Planet Smoothie',
#  'Queen of Sheba',
#  'Tapper Pub',
#  'The Missing Piece - Clearwater',
#  'The Great Giftsby',
#  'Orange Grove Dental - New Port Richey',
#  'Clearwater Social Brewing Company',
#  'Hampton Inn & Suites St. Petersburg/Downtown',
#  'Lane-Glo Bowl',
#  'Moniques Body Art',
#  'Cam Hair Designs',
#  '3am Liquor',
#  'Pop N Sons Diner',
#  'Big Island Poke',
#  'Gelato Cafe',
#  'Massage By Daryl',
#  'Islamorada Fish Company Restaurant',
#  'Fairfield Inn & Suites Tampa Fairgrounds/Casino',
#  'Lantower Cypress Creek',
#  'Bay City Sandwich Shop',
#  'Ratchada Thai Restaurant and Sushi Bar',
#  'Body Fuel',
#  'Tampa Bay Times',
#  'Karen Singer, MD',
#  "Gator's Dockside - Tampa",
#  "Doctors' Weight Loss Center",
#  'Owens & Sons Marine',
#  'Nathan Bangs & Associates',
#  'Salon Elements',
#  'Albert Whitted Park',
#  'Q Massage',
#  'Camden Pier District Apartments',
#  "Tom's Shoe Repair",
#  'Chef Tony Macaroni',
#  'Sushi Ushi',
#  'Outback Steakhouse',
#  'RumFish Grill',
#  'Central Alterations',
#  'If Trees Could Talk',
#  'Tampa Bay Brewing Company Westchase',
#  'Armada Games',
#  'Alpine Liquors',
#  'Mellow Mushroom - Brandon',
#  'Morton Plant Hospital',
#  'First Choice Moving and Storage',
#  'Strandhill Public Tampa Heights',
#  'Old Town Cafe',
#  'Urban Air Adventure Park - New Tampa',
#  "Hogan's Beach Shop",
#  'The London Bus Pub',
#  'Dickies BBQ',
#  'Massage of Trinity',
#  'Nam Viet Vietnamese Cuisine',
#  'Master Restoration',
#  ...]

# %%
businesses_df.loc[businesses_df["state"] == "FL"]
# Out:
#                    business_id                           name  \
# 7       qkRM_2X51Yqxk3btlwAQIg                 Temple Beth-El
# 10      UJsufbvfyfONHeWdvAHKjA                      Marshalls
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# 13      jaxMSoInw8Poo3XeMJt8lQ                   Adams Dental
# 14      0bPLkL0QhhPO5kt1_EXmNQ           Zio's Italian Market
# ...                        ...                            ...
# 150280  37G3SzO7RS1qSthACCG5SQ           Tampa Bay Club Sport
# 150289  Fck8i0fNQCa22ERz5Fa21w              Thoughtful Moving
# 150292  esBGrrmuZzSiECyRBoKvvA  Colony Grill - St. Petersburg
# 150317  Q7JYAMNzI1IpUd2edflmTA                      21 Barber
# 150345  jV_XOycEzSlTx-65W906pg                        Sic Ink
#
#                           address              city state postal_code  \
# 7              400 Pasadena Ave S    St. Petersburg    FL       33707
# 10      21705 Village Lakes Sc Dr     Land O' Lakes    FL       34639
# 11                                        Tampa Bay    FL       33602
# 13              15 N Missouri Ave        Clearwater    FL       33755
# 14                  2575 E Bay Dr             Largo    FL       33771
# ...                           ...               ...   ...         ...
# 150280       380 105th Terrace Ne  Saint Petersburg    FL       33716
# 150289          5004 E Fowler Ave             Tampa    FL       33617
# 150292            670 Central Ave    St. Petersburg    FL       33701
# 150317            10937 56th St N    Temple Terrace    FL       33617
# 150345      238 Apollo Beach Blvd      Apollo beach    FL       33572
#
#          latitude  longitude  stars  review_count  is_open  \
# 7       27.766590 -82.732983    3.5             5        1
# 10      28.190459 -82.457380    3.5             6        1
# 11      27.955269 -82.456320    4.0            10        1
# 13      27.966235 -82.787412    5.0            10        1
# 14      27.916116 -82.760461    4.5           100        0
# ...           ...        ...    ...           ...      ...
# 150280  27.867754 -82.632602    2.5             7        0
# 150289  28.054934 -82.400832    2.0            27        1
# 150292  27.770872 -82.643069    4.5            38        1
# 150317  28.047632 -82.393519    4.5            18        1
# 150345  27.771002 -82.394910    4.5             9        1
#
#                                                attributes  \
# 7                                                    None
# 10      {'RestaurantsPriceRange2': '2', 'BikeParking':...
# 11      {'Alcohol': ''none'', 'OutdoorSeating': 'None'...
# 13                          {'ByAppointmentOnly': 'True'}
# 14      {'OutdoorSeating': 'False', 'RestaurantsGoodFo...
# ...                                                   ...
# 150280                            {'GoodForKids': 'True'}
# 150289  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...
# 150292  {'RestaurantsPriceRange2': '2', 'RestaurantsAt...
# 150317  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 150345  {'WheelchairAccessible': 'True', 'BusinessAcce...
#
#                                                categories  \
# 7                     Synagogues, Religious Organizations
# 10                   Department Stores, Shopping, Fashion
# 11             Vietnamese, Food, Restaurants, Food Trucks
# 13      General Dentistry, Dentists, Health & Medical,...
# 14            Food, Delis, Italian, Bakeries, Restaurants
# ...                                                   ...
# 150280                          Active Life, Sports Clubs
# 150289  Packing Services, Home Services, Movers, Local...
# 150292  Bars, Beer Bar, Nightlife, Wine Bars, Pizza, R...
# 150317  Men's Hair Salons, Hair Salons, Barbers, Beaut...
# 150345  Beauty & Spas, Permanent Makeup, Piercing, Tattoo
#
#                                                     hours
# 7       {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...
# 10      {'Monday': '9:30-21:30', 'Tuesday': '9:30-21:3...
# 11      {'Monday': '11:0-14:0', 'Tuesday': '11:0-14:0'...
# 13      {'Monday': '7:30-15:30', 'Tuesday': '7:30-15:3...
# 14      {'Monday': '10:0-18:0', 'Tuesday': '10:0-20:0'...
# ...                                                   ...
# 150280                                               None
# 150289  {'Monday': '22:0-22:30', 'Tuesday': '8:0-19:0'...
# 150292  {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...
# 150317  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 150345  {'Tuesday': '12:0-19:0', 'Wednesday': '12:0-19...
#
# [26330 rows x 14 columns]

# %%
businesses_FL = businesses_df.loc[businesses_df["state"] == "FL", "business_id"].unique().tolist()

# %%
reviews_df.loc[reviews_df["business_id"].isin(businesses_FL)]
# Out:
#                       review_id                 user_id  \
# 10       rGQRf8UafX7OTlMNN19I8A  1WHRWwQmZOZDAhp2Qyny4g
# 15       OAhBYw8IQ6wlfw1owXWRWw  1C2lxzUo1Hyye4RFIXly3g
# 18       u2vzZaOqJ2feRshaaF1doQ  NDZvyYHTUWWu-kqgQzzDGQ
# 40       mO398Ed5dpv1H5ZsKc8KXw  yobeeTUBfaTBcnk26mXNuA
# 47       TcCcHzc3L6Aboq3DteEfZA  OuatwND396ZQxm2zK8WlUQ
# ...                         ...                     ...
# 6990233  kZiKvXxK7o5i7fa32u5Jgw  6jjHo9Lilv3kTy87pm2ycw
# 6990243  8yc7YWCe6lVU4RDmh-Ww1Q  3kJ4ktaXV-RVm49M-y1uTg
# 6990247  CphIcLTNU26TDb_YTOSgUQ  Is5IWDXWtqVMCVtedjJIQQ
# 6990261  34M6AEbY84174OBerbm96Q  i48cHEyRBl5g9_npYIG7dA
# 6990276  shTPgbgdwTHSuU67mGCmZQ  Zo0th2m8Ez4gLSbHftiQvg
#
#                     business_id  stars  useful  funny  cool  \
# 10       uMvVYRgGNXf5boolA9HXTw      5       2      0     0
# 15       BVndHaLihEYbr76Z0CMEGw      5       0      0     0
# 18       CLEWowfkj-wKYJlQDqT1aw      5       2      0     1
# 40       hKameFsaXh9g8WQbv593UA      4       0      0     0
# 47       jNL5KUPz2-tHUJM__ysSaw      1       1      0     0
# ...                         ...    ...     ...    ...   ...
# 6990233  pQAQwhBlSQdG1HuuLuCqXw      5      46     17    45
# 6990243  B2sF6QFCUFlfGb1QzWAyqg      3       0      0     0
# 6990247  VOITl4HlmC1EGJ_wVMS6_w      5       0      0     0
# 6990261  ReVpjIDupK_VMPn7ZxPvOQ      4       2      0     1
# 6990276  2vLksaMmSEcGbjI5gywpZA      5       2      1     2
#
#                                                       text  \
# 10       My experience with Shalimar was nothing but wo...
# 15       Great place for breakfast! I had the waffle, w...
# 18       I go to blow bar to get my brows done by natal...
# 40       Food was good- atmosphere/decor is like a fish...
# 47       If you want to pay for everything a la carte t...
# ...                                                    ...
# 6990233  Just $5 every SUNDAY in October! Do it!\n\nOh,...
# 6990243  My favorite place to pick up sports supplement...
# 6990247  I compete in Jiu-Jitsu and every competition I...
# 6990261  This place never fails the food is absolutely ...
# 6990276  This spot offers a great, affordable east week...
#
#                         date
# 10       2015-06-21 14:48:06
# 15       2014-10-11 16:22:06
# 18       2016-03-07 00:02:18
# 40       2015-04-15 15:30:48
# 47       2014-08-24 20:14:12
# ...                      ...
# 6990233  2020-10-11 00:09:30
# 6990243  2017-11-09 15:23:57
# 6990247  2018-11-09 18:09:35
# 6990261  2019-08-21 20:49:13
# 6990276  2021-03-31 16:55:10
#
# [1161545 rows x 9 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
